# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer

# %%
from modelPractice.Model import Model
class PLA(Model):
    def __init__(self,X,y,with_regular=False,penalty='l1',C=1.0):
        super().__init__(name='Perceptron Learning Algorithm')
        self.n_samples,self.n_features = X.shape
        self.X = np.array(X) # (n_samples,n_features)
        self.y = [1 if y_val==1 else -1 for y_val in y]
        self.y = np.array(self.y)
        self.bias = 0
        self.weights = self.initWeight()
        self.n = np.zeros(self.n_samples)
    def initWeight(self):
        """初始化权重(1,n_features)"""
        return np.random.rand(self.n_features)
    @staticmethod
    def sign(scores):
        return np.sign(scores)
    def compute(self,X):
        """return (n_samples,1)"""
        return np.dot(X,self.weights.T) + self.bias
    def loss(self,X,y):
        """错分类点距分割平面的距离"""
        scores = self.compute(X)
        pred = self.sign(scores)
        loss = 0
        count = 0
        for index,y_real in enumerate(y):
            if y_real != pred[index]:
                loss += scores[index]
                count += 1
        return loss / count
    def train(self,epochs=100,learning_rate=0.1):
        for epoch in range(epochs):
            print(">>>>>第{}轮训练>>>>>>".format(epoch))
            for index,x in enumerate(self.X):
                score = np.dot(x,self.weights.T) + self.bias
                pred = np.sign(score)
                if pred != self.y[index]:
                    self.weights = self.weights + learning_rate * self.y[index] * x
                    self.bias = self.bias + learning_rate * self.y[index]   
            print(">>>>>loss：{}".format(self.loss(self.X,self.y)))
    def trainDual(self,epochs=100,learning_rate=0.1):
        """对偶形式"""
        grams = self.gram()
        for epoch in range(epochs):
            print(">>>>>第{}轮训练>>>>>>".format(epoch))
            for index,x in enumerate(self.X):
                sum_t = np.sum(self.n * learning_rate * grams[index]) + np.sum(self.n * learning_rate * self.y)
                if self.y[index] * sum_t <= 0:
                    self.n[index] += 1
    def gram(self):
        return self.X @ self.X.T 
    def predict(self,X_test,y_test):
        scores = self.compute(X_test)
        pred = self.sign(scores)
        y_test = [1 if y_val==1 else -1 for y_val in y_test]
        return np.sum([y_test[index]==pred[index] for index in range(len(y_test))]) / len(y_test)
    def predictDual(self,X_test,y_test):
        """对偶形式的预测"""
        self.weights = np.sum(self.n*learning_rate*self.y*self.X,axis=1,keepdims=True)
        self.bias = np.sum(self.n*learning_rate*self.y,axis=1,keepdims=True)
        scores = self.compute(X_test)
        pred = self.sign(scores)
        y_test = [1 if y_val==1 else -1 for y_val in y_test]
        return np.sum([y_test[index]==pred[index] for index in range(len(y_test))]) / len(y_test)

# %%
data = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(data['data'], data['target'], test_size=0.3)
pla = PLA(X_train,y_train)

# %%
pla.train(200,learning_rate=0.3)
# Out:
# >>>>>第0轮训练>>>>>>
# >>>>>loss：352472.199506851
# >>>>>第1轮训练>>>>>>
# >>>>>loss：220922.01640743864
# >>>>>第2轮训练>>>>>>
# >>>>>loss：69598.0114904969
# >>>>>第3轮训练>>>>>>
# >>>>>loss：174647.0283700827
# >>>>>第4轮训练>>>>>>
# >>>>>loss：187724.141813181
# >>>>>第5轮训练>>>>>>
# >>>>>loss：83878.96964081103
# >>>>>第6轮训练>>>>>>
# >>>>>loss：112292.76879331352
# >>>>>第7轮训练>>>>>>
# >>>>>loss：117282.28997216347
# >>>>>第8轮训练>>>>>>
# >>>>>loss：160709.73957882327
# >>>>>第9轮训练>>>>>>
# >>>>>loss：107818.88257575271
# >>>>>第10轮训练>>>>>>
# >>>>>loss：137500.68148144486
# >>>>>第11轮训练>>>>>>
# >>>>>loss：149361.27577871567
# >>>>>第12轮训练>>>>>>
# >>>>>loss：140620.52337511236
# >>>>>第13轮训练>>>>>>
# >>>>>loss：136891.7025993227
# >>>>>第14轮训练>>>>>>
# >>>>>loss：172871.15440785442
# >>>>>第15轮训练>>>>>>
# >>>>>loss：158337.78350493818
# >>>>>第16轮训练>>>>>>
# >>>>>loss：150558.15878781743
# >>>>>第17轮训练>>>>>>
# >>>>>loss：147180.81972925516
# >>>>>第18轮训练>>>>>>
# >>>>>loss：161423.1212262091
# >>>>>第19轮训练>>>>>>
# >>>>>loss：137082.8816439626
# >>>>>第20轮训练>>>>>>
# >>>>>loss：163485.88753076427
# >>>>>第21轮训练>>>>>>
# >>>>>loss：138957.99680404845
# >>>>>第22轮训练>>>>>>
# >>>>>loss：164926.71785045878
# >>>>>第23轮训练>>>>>>
# >>>>>loss：175958.4343663803
# >>>>>第24轮训练>>>>>>
# >>>>>loss：165334.81525358756
# >>>>>第25轮训练>>>>>>
# >>>>>loss：165402.02501712152
# >>>>>第26轮训练>>>>>>
# >>>>>loss：161625.2741395767
# >>>>>第27轮训练>>>>>>
# >>>>>loss：165897.09987112635
# >>>>>第28轮训练>>>>>>
# >>>>>loss：160607.67516813867
# >>>>>第29轮训练>>>>>>
# >>>>>loss：165015.94823881515
# >>>>>第30轮训练>>>>>>
# >>>>>loss：159865.76962097498
# >>>>>第31轮训练>>>>>>
# >>>>>loss：176054.5331471824
# >>>>>第32轮训练>>>>>>
# >>>>>loss：171026.27643823516
# >>>>>第33轮训练>>>>>>
# >>>>>loss：113508.48554912902
# >>>>>第34轮训练>>>>>>
# >>>>>loss：171606.7586255009
# >>>>>第35轮训练>>>>>>
# >>>>>loss：163093.10250134545
# >>>>>第36轮训练>>>>>>
# >>>>>loss：132704.27229501447
# >>>>>第37轮训练>>>>>>
# >>>>>loss：148135.63800064294
# >>>>>第38轮训练>>>>>>
# >>>>>loss：133259.59677133017
# >>>>>第39轮训练>>>>>>
# >>>>>loss：131822.99385067815
# >>>>>第40轮训练>>>>>>
# >>>>>loss：179865.4180263598
# >>>>>第41轮训练>>>>>>
# >>>>>loss：188380.2064115953
# >>>>>第42轮训练>>>>>>
# >>>>>loss：130521.89253310476
# >>>>>第43轮训练>>>>>>
# >>>>>loss：129085.28961245282
# >>>>>第44轮训练>>>>>>
# >>>>>loss：146254.22657994286
# >>>>>第45轮训练>>>>>>
# >>>>>loss：165123.19476545567
# >>>>>第46轮训练>>>>>>
# >>>>>loss：167105.69267985167
# >>>>>第47轮训练>>>>>>
# >>>>>loss：156830.9650656396
# >>>>>第48轮训练>>>>>>
# >>>>>loss：162125.67727386268
# >>>>>第49轮训练>>>>>>
# >>>>>loss：163593.14099609313
# >>>>>第50轮训练>>>>>>
# >>>>>loss：165575.63891048913
# >>>>>第51轮训练>>>>>>
# >>>>>loss：167558.136824885
# >>>>>第52轮训练>>>>>>
# >>>>>loss：169540.63473928114
# >>>>>第53轮训练>>>>>>
# >>>>>loss：171523.132653677
# >>>>>第54轮训练>>>>>>
# >>>>>loss：173505.63056807284
# >>>>>第55轮训练>>>>>>
# >>>>>loss：272193.35523775296
# >>>>>第56轮训练>>>>>>
# >>>>>loss：161883.54585012834
# >>>>>第57轮训练>>>>>>
# >>>>>loss：155599.19095403774
# >>>>>第58轮训练>>>>>>
# >>>>>loss：256709.15395814882
# >>>>>第59轮训练>>>>>>
# >>>>>loss：258430.4761874475
# >>>>>第60轮训练>>>>>>
# >>>>>loss：255624.5692288069
# >>>>>第61轮训练>>>>>>
# >>>>>loss：252818.66227016645
# >>>>>第62轮训练>>>>>>
# >>>>>loss：152853.67054493757
# >>>>>第63轮训练>>>>>>
# >>>>>loss：261539.33372778454
# >>>>>第64轮训练>>>>>>
# >>>>>loss：260257.5543354463
# >>>>>第65轮训练>>>>>>
# >>>>>loss：258975.77494310756
# >>>>>第66轮训练>>>>>>
# >>>>>loss：152989.525409801
# >>>>>第67轮训练>>>>>>
# >>>>>loss：263179.8664602052
# >>>>>第68轮训练>>>>>>
# >>>>>loss：261898.08706786664
# >>>>>第69轮训练>>>>>>
# >>>>>loss：92212.15813131232
# >>>>>第70轮训练>>>>>>
# >>>>>loss：142582.75494587747
# >>>>>第71轮训练>>>>>>
# >>>>>loss：147207.92271681287
# >>>>>第72轮训练>>>>>>
# >>>>>loss：135996.12923597154
# >>>>>第73轮训练>>>>>>
# >>>>>loss：271477.66159907763
# >>>>>第74轮训练>>>>>>
# >>>>>loss：90496.62895763878
# >>>>>第75轮训练>>>>>>
# >>>>>loss：144957.530277714
# >>>>>第76轮训练>>>>>>
# >>>>>loss：137197.81711173124
# >>>>>第77轮训练>>>>>>
# >>>>>loss：272865.09060149564
# >>>>>第78轮训练>>>>>>
# >>>>>loss：136121.43868472843
# >>>>>第79轮训练>>>>>>
# >>>>>loss：140746.60645566386
# >>>>>第80轮训练>>>>>>
# >>>>>loss：136430.55319500723
# >>>>>第81轮训练>>>>>>
# >>>>>loss：180372.61432407168
# >>>>>第82轮训练>>>>>>
# >>>>>loss：92431.68155520501
# >>>>>第83轮训练>>>>>>
# >>>>>loss：110017.74527732246
# >>>>>第84轮训练>>>>>>
# >>>>>loss：263195.4975723855
# >>>>>第85轮训练>>>>>>
# >>>>>loss：262790.1386572986
# >>>>>第86轮训练>>>>>>
# >>>>>loss：252868.76735285233
# >>>>>第87轮训练>>>>>>
# >>>>>loss：267828.4032081184
# >>>>>第88轮训练>>>>>>
# >>>>>loss：105767.94164959095
# >>>>>第89轮训练>>>>>>
# >>>>>loss：252502.91551556095
# >>>>>第90轮训练>>>>>>
# >>>>>loss：259750.08252878697
# >>>>>第91轮训练>>>>>>
# >>>>>loss：310156.8778440332
# >>>>>第92轮训练>>>>>>
# >>>>>loss：142438.14033428294
# >>>>>第93轮训练>>>>>>
# >>>>>loss：111615.22574684407
# >>>>>第94轮训练>>>>>>
# >>>>>loss：104293.73875811505
# >>>>>第95轮训练>>>>>>
# >>>>>loss：166338.34299101177
# >>>>>第96轮训练>>>>>>
# >>>>>loss：248300.98747233296
# >>>>>第97轮训练>>>>>>
# >>>>>loss：265363.75305807043
# >>>>>第98轮训练>>>>>>
# >>>>>loss：165061.1871832475
# >>>>>第99轮训练>>>>>>
# >>>>>loss：167663.93936542273
# >>>>>第100轮训练>>>>>>
# >>>>>loss：249381.92725129327
# >>>>>第101轮训练>>>>>>
# >>>>>loss：167349.08705233745
# >>>>>第102轮训练>>>>>>
# >>>>>loss：111807.07715821758
# >>>>>第103轮训练>>>>>>
# >>>>>loss：108373.58242122257
# >>>>>第104轮训练>>>>>>
# >>>>>loss：165877.06915680523
# >>>>>第105轮训练>>>>>>
# >>>>>loss：168479.82133898037
# >>>>>第106轮训练>>>>>>
# >>>>>loss：168568.79366290558
# >>>>>第107轮训练>>>>>>
# >>>>>loss：168657.76598683087
# >>>>>第108轮训练>>>>>>
# >>>>>loss：168746.738310756
# >>>>>第109轮训练>>>>>>
# >>>>>loss：164722.13436355733
# >>>>>第110轮训练>>>>>>
# >>>>>loss：164822.53259988475
# >>>>>第111轮训练>>>>>>
# >>>>>loss：213525.04391289665
# >>>>>第112轮训练>>>>>>
# >>>>>loss：173129.77010271559
# >>>>>第113轮训练>>>>>>
# >>>>>loss：112459.34961996933
# >>>>>第114轮训练>>>>>>
# >>>>>loss：218436.91944632403
# >>>>>第115轮训练>>>>>>
# >>>>>loss：223148.9991002656
# >>>>>第116轮训练>>>>>>
# >>>>>loss：166492.08106399124
# >>>>>第117轮训练>>>>>>
# >>>>>loss：171707.95243745303
# >>>>>第118轮训练>>>>>>
# >>>>>loss：225521.71572432545
# >>>>>第119轮训练>>>>>>
# >>>>>loss：160023.87174904032
# >>>>>第120轮训练>>>>>>
# >>>>>loss：163296.1162504929
# >>>>>第121轮训练>>>>>>
# >>>>>loss：223576.84412536846
# >>>>>第122轮训练>>>>>>
# >>>>>loss：100457.19742073119
# >>>>>第123轮训练>>>>>>
# >>>>>loss：195676.2302062218
# >>>>>第124轮训练>>>>>>
# >>>>>loss：229918.15213382477
# >>>>>第125轮训练>>>>>>
# >>>>>loss：224062.39175899109
# >>>>>第126轮训练>>>>>>
# >>>>>loss：194792.17244407395
# >>>>>第127轮训练>>>>>>
# >>>>>loss：106953.62377139866
# >>>>>第128轮训练>>>>>>
# >>>>>loss：221760.77530199813
# >>>>>第129轮训练>>>>>>
# >>>>>loss：152217.71545529665
# >>>>>第130轮训练>>>>>>
# >>>>>loss：155489.95995674908
# >>>>>第131轮训练>>>>>>
# >>>>>loss：228564.5908219908
# >>>>>第132轮训练>>>>>>
# >>>>>loss：223504.97858816618
# >>>>>第133轮训练>>>>>>
# >>>>>loss：154140.17816142665
# >>>>>第134轮训练>>>>>>
# >>>>>loss：229232.8917158656
# >>>>>第135轮训练>>>>>>
# >>>>>loss：220042.1503349279
# >>>>>第136轮训练>>>>>>
# >>>>>loss：190660.2207765081
# >>>>>第137轮训练>>>>>>
# >>>>>loss：238355.42915668487
# >>>>>第138轮训练>>>>>>
# >>>>>loss：189433.22628157784
# >>>>>第139轮训练>>>>>>
# >>>>>loss：237102.35574611215
# >>>>>第140轮训练>>>>>>
# >>>>>loss：188206.23178664723
# >>>>>第141轮训练>>>>>>
# >>>>>loss：235849.28233553935
# >>>>>第142轮训练>>>>>>
# >>>>>loss：186979.23729171723
# >>>>>第143轮训练>>>>>>
# >>>>>loss：228142.32427916973
# >>>>>第144轮训练>>>>>>
# >>>>>loss：224679.92911688378
# >>>>>第145轮训练>>>>>>
# >>>>>loss：229923.18232274693
# >>>>>第146轮训练>>>>>>
# >>>>>loss：226361.14079865097
# >>>>>第147轮训练>>>>>>
# >>>>>loss：227605.01916258017
# >>>>>第148轮训练>>>>>>
# >>>>>loss：193011.1225127187
# >>>>>第149轮训练>>>>>>
# >>>>>loss：193123.63135323234
# >>>>>第150轮训练>>>>>>
# >>>>>loss：193236.14019374596
# >>>>>第151轮训练>>>>>>
# >>>>>loss：235671.39441439134
# >>>>>第152轮训练>>>>>>
# >>>>>loss：191993.86280152953
# >>>>>第153轮训练>>>>>>
# >>>>>loss：192106.37164204326
# >>>>>第154轮训练>>>>>>
# >>>>>loss：192218.880482557
# >>>>>第155轮训练>>>>>>
# >>>>>loss：192331.38932307062
# >>>>>第156轮训练>>>>>>
# >>>>>loss：187761.14715256589
# >>>>>第157轮训练>>>>>>
# >>>>>loss：187882.34193215435
# >>>>>第158轮训练>>>>>>
# >>>>>loss：188003.53671174272
# >>>>>第159轮训练>>>>>>
# >>>>>loss：188124.73149133116
# >>>>>第160轮训练>>>>>>
# >>>>>loss：188245.9262709194
# >>>>>第161轮训练>>>>>>
# >>>>>loss：235459.96126071524
# >>>>>第162轮训练>>>>>>
# >>>>>loss：187018.9317759892
# >>>>>第163轮训练>>>>>>
# >>>>>loss：187140.12655557756
# >>>>>第164轮训练>>>>>>
# >>>>>loss：187261.32133516597
# >>>>>第165轮训练>>>>>>
# >>>>>loss：187382.51611475443
# >>>>>第166轮训练>>>>>>
# >>>>>loss：187503.71089434283
# >>>>>第167轮训练>>>>>>
# >>>>>loss：187624.90567393112
# >>>>>第168轮训练>>>>>>
# >>>>>loss：187746.10045351958
# >>>>>第169轮训练>>>>>>
# >>>>>loss：187867.29523310796
# >>>>>第170轮训练>>>>>>
# >>>>>loss：187988.49001269636
# >>>>>第171轮训练>>>>>>
# >>>>>loss：188109.6847922848
# >>>>>第172轮训练>>>>>>
# >>>>>loss：235378.73313915086
# >>>>>第173轮训练>>>>>>
# >>>>>loss：233583.36556578637
# >>>>>第174轮训练>>>>>>
# >>>>>loss：203144.59337603563
# >>>>>第175轮训练>>>>>>
# >>>>>loss：188008.97103222302
# >>>>>第176轮训练>>>>>>
# >>>>>loss：222307.71008291806
# >>>>>第177轮训练>>>>>>
# >>>>>loss：222271.55284689405
# >>>>>第178轮训练>>>>>>
# >>>>>loss：218932.62171773065
# >>>>>第179轮训练>>>>>>
# >>>>>loss：233588.4816503606
# >>>>>第180轮训练>>>>>>
# >>>>>loss：208283.5947302951
# >>>>>第181轮训练>>>>>>
# >>>>>loss：218819.5633454282
# >>>>>第182轮训练>>>>>>
# >>>>>loss：227366.3450089802
# >>>>>第183轮训练>>>>>>
# >>>>>loss：221655.13932739568
# >>>>>第184轮训练>>>>>>
# >>>>>loss：218316.20819823214
# >>>>>第185轮训练>>>>>>
# >>>>>loss：232883.1494192707
# >>>>>第186轮训练>>>>>>
# >>>>>loss：202656.49129795577
# >>>>>第187轮训练>>>>>>
# >>>>>loss：218203.14982592978
# >>>>>第188轮训练>>>>>>
# >>>>>loss：226819.98771372536
# >>>>>第189轮训练>>>>>>
# >>>>>loss：187326.92797753186
# >>>>>第190轮训练>>>>>>
# >>>>>loss：218361.38005109338
# >>>>>第191轮训练>>>>>>
# >>>>>loss：230916.97972269624
# >>>>>第192轮训练>>>>>>
# >>>>>loss：195796.7889845333
# >>>>>第193轮训练>>>>>>
# >>>>>loss：188510.4259467132
# >>>>>第194轮训练>>>>>>
# >>>>>loss：228031.65088199635
# >>>>>第195轮训练>>>>>>
# >>>>>loss：203772.29903823131
# >>>>>第196轮训练>>>>>>
# >>>>>loss：231159.98298257324
# >>>>>第197轮训练>>>>>>
# >>>>>loss：198481.283266387
# >>>>>第198轮训练>>>>>>
# >>>>>loss：195823.28551010918
# >>>>>第199轮训练>>>>>>
# >>>>>loss：230717.26428801613

# %%
pla.predict(X_test,y_test)
# Out:
# 0.9239766081871345

# %%
pla.trainDual(200,learning_rate=0.3)
# Out:
# >>>>>第0轮训练>>>>>>
# >>>>>第1轮训练>>>>>>
# >>>>>第2轮训练>>>>>>
# >>>>>第3轮训练>>>>>>
# >>>>>第4轮训练>>>>>>
# >>>>>第5轮训练>>>>>>
# >>>>>第6轮训练>>>>>>
# >>>>>第7轮训练>>>>>>
# >>>>>第8轮训练>>>>>>
# >>>>>第9轮训练>>>>>>
# >>>>>第10轮训练>>>>>>
# >>>>>第11轮训练>>>>>>
# >>>>>第12轮训练>>>>>>
# >>>>>第13轮训练>>>>>>
# >>>>>第14轮训练>>>>>>
# >>>>>第15轮训练>>>>>>
# >>>>>第16轮训练>>>>>>
# >>>>>第17轮训练>>>>>>
# >>>>>第18轮训练>>>>>>
# >>>>>第19轮训练>>>>>>
# >>>>>第20轮训练>>>>>>
# >>>>>第21轮训练>>>>>>
# >>>>>第22轮训练>>>>>>
# >>>>>第23轮训练>>>>>>
# >>>>>第24轮训练>>>>>>
# >>>>>第25轮训练>>>>>>
# >>>>>第26轮训练>>>>>>
# >>>>>第27轮训练>>>>>>
# >>>>>第28轮训练>>>>>>
# >>>>>第29轮训练>>>>>>
# >>>>>第30轮训练>>>>>>
# >>>>>第31轮训练>>>>>>
# >>>>>第32轮训练>>>>>>
# >>>>>第33轮训练>>>>>>
# >>>>>第34轮训练>>>>>>
# >>>>>第35轮训练>>>>>>
# >>>>>第36轮训练>>>>>>
# >>>>>第37轮训练>>>>>>
# >>>>>第38轮训练>>>>>>
# >>>>>第39轮训练>>>>>>
# >>>>>第40轮训练>>>>>>
# >>>>>第41轮训练>>>>>>
# >>>>>第42轮训练>>>>>>
# >>>>>第43轮训练>>>>>>
# >>>>>第44轮训练>>>>>>
# >>>>>第45轮训练>>>>>>
# >>>>>第46轮训练>>>>>>
# >>>>>第47轮训练>>>>>>
# >>>>>第48轮训练>>>>>>
# >>>>>第49轮训练>>>>>>
# >>>>>第50轮训练>>>>>>
# >>>>>第51轮训练>>>>>>
# >>>>>第52轮训练>>>>>>
# >>>>>第53轮训练>>>>>>
# >>>>>第54轮训练>>>>>>
# >>>>>第55轮训练>>>>>>
# >>>>>第56轮训练>>>>>>
# >>>>>第57轮训练>>>>>>
# >>>>>第58轮训练>>>>>>
# >>>>>第59轮训练>>>>>>
# >>>>>第60轮训练>>>>>>
# >>>>>第61轮训练>>>>>>
# >>>>>第62轮训练>>>>>>
# >>>>>第63轮训练>>>>>>
# >>>>>第64轮训练>>>>>>
# >>>>>第65轮训练>>>>>>
# >>>>>第66轮训练>>>>>>
# >>>>>第67轮训练>>>>>>
# >>>>>第68轮训练>>>>>>
# >>>>>第69轮训练>>>>>>
# >>>>>第70轮训练>>>>>>
# >>>>>第71轮训练>>>>>>
# >>>>>第72轮训练>>>>>>
# >>>>>第73轮训练>>>>>>
# >>>>>第74轮训练>>>>>>
# >>>>>第75轮训练>>>>>>
# >>>>>第76轮训练>>>>>>
# >>>>>第77轮训练>>>>>>
# >>>>>第78轮训练>>>>>>
# >>>>>第79轮训练>>>>>>
# >>>>>第80轮训练>>>>>>
# >>>>>第81轮训练>>>>>>
# >>>>>第82轮训练>>>>>>
# >>>>>第83轮训练>>>>>>
# >>>>>第84轮训练>>>>>>
# >>>>>第85轮训练>>>>>>
# >>>>>第86轮训练>>>>>>
# >>>>>第87轮训练>>>>>>
# >>>>>第88轮训练>>>>>>
# >>>>>第89轮训练>>>>>>
# >>>>>第90轮训练>>>>>>
# >>>>>第91轮训练>>>>>>
# >>>>>第92轮训练>>>>>>
# >>>>>第93轮训练>>>>>>
# >>>>>第94轮训练>>>>>>
# >>>>>第95轮训练>>>>>>
# >>>>>第96轮训练>>>>>>
# >>>>>第97轮训练>>>>>>
# >>>>>第98轮训练>>>>>>
# >>>>>第99轮训练>>>>>>
# >>>>>第100轮训练>>>>>>
# >>>>>第101轮训练>>>>>>
# >>>>>第102轮训练>>>>>>
# >>>>>第103轮训练>>>>>>
# >>>>>第104轮训练>>>>>>
# >>>>>第105轮训练>>>>>>
# >>>>>第106轮训练>>>>>>
# >>>>>第107轮训练>>>>>>
# >>>>>第108轮训练>>>>>>
# >>>>>第109轮训练>>>>>>
# >>>>>第110轮训练>>>>>>
# >>>>>第111轮训练>>>>>>
# >>>>>第112轮训练>>>>>>
# >>>>>第113轮训练>>>>>>
# >>>>>第114轮训练>>>>>>
# >>>>>第115轮训练>>>>>>
# >>>>>第116轮训练>>>>>>
# >>>>>第117轮训练>>>>>>
# >>>>>第118轮训练>>>>>>
# >>>>>第119轮训练>>>>>>
# >>>>>第120轮训练>>>>>>
# >>>>>第121轮训练>>>>>>
# >>>>>第122轮训练>>>>>>
# >>>>>第123轮训练>>>>>>
# >>>>>第124轮训练>>>>>>
# >>>>>第125轮训练>>>>>>
# >>>>>第126轮训练>>>>>>
# >>>>>第127轮训练>>>>>>
# >>>>>第128轮训练>>>>>>
# >>>>>第129轮训练>>>>>>
# >>>>>第130轮训练>>>>>>
# >>>>>第131轮训练>>>>>>
# >>>>>第132轮训练>>>>>>
# >>>>>第133轮训练>>>>>>
# >>>>>第134轮训练>>>>>>
# >>>>>第135轮训练>>>>>>
# >>>>>第136轮训练>>>>>>
# >>>>>第137轮训练>>>>>>
# >>>>>第138轮训练>>>>>>
# >>>>>第139轮训练>>>>>>
# >>>>>第140轮训练>>>>>>
# >>>>>第141轮训练>>>>>>
# >>>>>第142轮训练>>>>>>
# >>>>>第143轮训练>>>>>>
# >>>>>第144轮训练>>>>>>
# >>>>>第145轮训练>>>>>>
# >>>>>第146轮训练>>>>>>
# >>>>>第147轮训练>>>>>>
# >>>>>第148轮训练>>>>>>
# >>>>>第149轮训练>>>>>>
# >>>>>第150轮训练>>>>>>
# >>>>>第151轮训练>>>>>>
# >>>>>第152轮训练>>>>>>
# >>>>>第153轮训练>>>>>>
# >>>>>第154轮训练>>>>>>
# >>>>>第155轮训练>>>>>>
# >>>>>第156轮训练>>>>>>
# >>>>>第157轮训练>>>>>>
# >>>>>第158轮训练>>>>>>
# >>>>>第159轮训练>>>>>>
# >>>>>第160轮训练>>>>>>
# >>>>>第161轮训练>>>>>>
# >>>>>第162轮训练>>>>>>
# >>>>>第163轮训练>>>>>>
# >>>>>第164轮训练>>>>>>
# >>>>>第165轮训练>>>>>>
# >>>>>第166轮训练>>>>>>
# >>>>>第167轮训练>>>>>>
# >>>>>第168轮训练>>>>>>
# >>>>>第169轮训练>>>>>>
# >>>>>第170轮训练>>>>>>
# >>>>>第171轮训练>>>>>>
# >>>>>第172轮训练>>>>>>
# >>>>>第173轮训练>>>>>>
# >>>>>第174轮训练>>>>>>
# >>>>>第175轮训练>>>>>>
# >>>>>第176轮训练>>>>>>
# >>>>>第177轮训练>>>>>>
# >>>>>第178轮训练>>>>>>
# >>>>>第179轮训练>>>>>>
# >>>>>第180轮训练>>>>>>
# >>>>>第181轮训练>>>>>>
# >>>>>第182轮训练>>>>>>
# >>>>>第183轮训练>>>>>>
# >>>>>第184轮训练>>>>>>
# >>>>>第185轮训练>>>>>>
# >>>>>第186轮训练>>>>>>
# >>>>>第187轮训练>>>>>>
# >>>>>第188轮训练>>>>>>
# >>>>>第189轮训练>>>>>>
# >>>>>第190轮训练>>>>>>
# >>>>>第191轮训练>>>>>>
# >>>>>第192轮训练>>>>>>
# >>>>>第193轮训练>>>>>>
# >>>>>第194轮训练>>>>>>
# >>>>>第195轮训练>>>>>>
# >>>>>第196轮训练>>>>>>
# >>>>>第197轮训练>>>>>>
# >>>>>第198轮训练>>>>>>
# >>>>>第199轮训练>>>>>>

# %%
pla.predictDual(X_test,y_test)
